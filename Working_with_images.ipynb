# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-2df08a7d-6885-4b8e-a0eb-cf18aea10eb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2df08a7d-6885-4b8e-a0eb-cf18aea10eb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Frame_00009.png to Frame_00009.png
# Saving Frame_00019.png to Frame_00019.png
# Saving Frame_00029.png to Frame_00029.png
# Saving Frame_00039.png to Frame_00039.png
# Saving Frame_00049.png to Frame_00049.png
# Saving Frame_00059.png to Frame_00059.png
# Saving Frame_00069.png to Frame_00069.png
# Saving Frame_00079.png to Frame_00079.png
# Saving Frame_00089.png to Frame_00089.png
# Saving Frame_00099.png to Frame_00099.png
# Saving Frame_00109.png to Frame_00109.png
# Saving Frame_00119.png to Frame_00119.png
# ...

# %%
from google.colab.patches import cv2_imshow
from skimage import io

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
filedir = '/content/drive/MyDrive/Colab_Notebooks/3D_GANS/train/fractals_images/' #update it according your folder structure where you downloaded the images

# %%
import matplotlib.pyplot as plt

# %%
def show_images(images, figsize=(20,10), columns = 5):
  plt.figure(figsize=figsize)
  for i, image in enumerate(images):
      plt.subplot(len(images) / columns + 1, columns, i + 1)
      plt.imshow(image)

# %%
from google.colab.patches import cv2_imshow
from skimage import io

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image


def img_reshape(img):
    img = Image.open(filedir+img).convert('RGB')
    img = img.resize((300,200))
    img = np.asarray(img)
    return img

# %%
images = os.listdir(filedir)
img_arr = []

# %%
for image in images:
    img_arr.append(img_reshape(image))

# %%
pil_im = img_reshape('Frame_00009.png')
plt.imshow(np.asarray(pil_im))

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

fig = plt.figure(figsize=(22., 22.))
grid = ImageGrid(fig, 111, 
                 nrows_ncols=(16, 16),  # creates grid of axes
                 axes_pad=0.1,  # pad between axes
                 )

for ax, im in zip(grid, img_arr):
    ax.imshow(im)

plt.show()
